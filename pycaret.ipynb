# %%
from pycaret.classification import *
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import pandas as pd

# %%
# importer les données d'apprentissage
data = pd.read_csv('df2010-2021.csv')

# %%
data
# Out:
#         popularity  duration_ms  explicit release_date  danceability  energy  \
# 0               41       159560         0   2020-03-13         0.671   0.867
# 1               26       187333         0   2018-05-04         0.319   0.201
# 2               25       236800         0   2018-05-04         0.269   0.129
# 3               18       313093         0   2020-10-30         0.644   0.212
# 4               18       295093         0   2020-10-30         0.627   0.184
# ...            ...          ...       ...          ...           ...     ...
# 125458          50       258267         0   2020-09-26         0.560   0.518
# 125459          72       153293         0   2020-10-21         0.765   0.663
# 125460          70       187601         0   2020-09-02         0.535   0.314
# 125461          58       142003         0   2021-03-05         0.696   0.615
# 125462          38       214360         0   2015-07-01         0.686   0.723
#
# ...

# %%
from pycaret.classification import setup

# %%
import pycaret

# %%
pycaret
# Out:
# <module 'pycaret' from '/home/yanis/miniconda3/envs/pycaret_env/lib/python3.8/site-packages/pycaret/__init__.py'>

# %%
session = setup(data=data, normalize=True,target='popularity',train_size=0.7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 session = setup(data=data, normalize=True,target='popularity',train_size=0.7)
#
# ...

# %%
# définir un modèle
clf = setup(data, target = 'target_column')

# entraîner plusieurs modèles
model_1 = create_model('xgboost')
model_2 = create_model('lightgbm')
model_3 = create_model('catboost')

# comparer les résultats
compare_models()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 # définir un modèle
# ----> 2 clf = setup(data, target = 'target_column')
#       4 # entraîner plusieurs modèles
#       5 model_1 = create_model('xgboost')
#
# ...
